# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Extracting/Formatting the datas

# %%
dataset = pd.read_csv('/Users/louise_monciero/Desktop/APU/Machine_Learning/Assignement/out copie.csv')

# Balancing the entries based on TV (=['label'])
phishing_sample = dataset[dataset['label'] == 'phishing'].sample(n=100000, random_state=42)
legitimate_sample = dataset[dataset['label'] == 'legitimate'].sample(n=100000, random_state=42)
dataset_sample = pd.concat([phishing_sample, legitimate_sample])

dataset_sample.drop(columns=['source'])
# Out:
#                                                        url       label  \
# 1336823  http://sub22b.jelastic.regruhosting.ru/acesso/...    phishing
# 2029023  https://cherry-609d.hakeem1115.workers.dev/63f...    phishing
# 2061773  http://secureid-auth5b.serveirc.com/navyfedera...    phishing
# 2346555                           https://turnamenpubg.com    phishing
# 1637629  http://www.v2postch.com/SwissPost/a4bc4ecdab6c...    phishing
# ...                                                    ...         ...
# 229524                         onlinedigitalpublishing.com  legitimate
# 139550                static-fotomoto-com.s3.amazonaws.com  legitimate
# 439175                                     kurzfilmtag.com  legitimate
# 581400                                           52wmb.com  legitimate
# 1238816  alb-q0i3azj94txpdvoxac.ap-southeast-1.alb.aliy...  legitimate
#
#          url_length  starts_with_ip  url_entropy  has_punycode  \
# ...

# %% [markdown]
# ## Verification

# %%
dataset_sample.shape
dataset_sample['label'].describe()
# Out:
# count       200000
# unique           2
# top       phishing
# freq        100000
# Name: label, dtype: object

# %%
plt.hist(dataset_sample['label'], density=False, bins= 3 ) # attribut ??
# Out:
# (array([100000.,      0., 100000.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# ## Saving

# %%
# To csv
dataset_sample.to_csv('/Users/louise_monciero/Desktop/APU/Machine_Learning/Assignement/sample_output_WAY_larger.csv', index=False)
